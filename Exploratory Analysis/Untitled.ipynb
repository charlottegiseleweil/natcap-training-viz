# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data18 = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name='2018')
data18.head()
# Out:
#   P/I                  NAME                      E-MAIL    AFFILIATION \nTYPE  \
# 0   P  Susana Beatriz Adamo  sadamo@ciesin.columbia.edu              Academia
# 1   P             SoEun Ahn             seahn@kei.re.kr                   NaN
# 2   P     Mustapha Alhassan                         NaN                   NaN
# 3   P           Karen Allen      karen.allen@furman.edu  Academia; Government
# 4   P      Ginger Allington          gallington@gwu.edu              Academia
#
#               AFFILIATION\nNAME        COUNTRY       TYPE      COUNTRY.1  \
# 0    CIESIN-Columbia University  United States  Symposium  United States
# 1   Korea Environment Institute    South Korea  Symposium  United States
# 2                           NaN            NaN  Symposium  United States
# 3             Furman University  United States  Symposium  United States
# 4  George Washington University  United States  Symposium  United States
#
#   START\nDATE  LENGTH\n(# OF DAYS)  100 LEVEL\n(INTRO)  \
# ...

# %%
data17 = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name='2017')
data17.head()
# Out:
#   P/I               NAME                     E-MAIL AFFILIATION \nTYPE  \
# 0   P       Roxana MIHAI       roxana.mihai@anpm.ro         Government
# 1   P      Roxana STOIAN      roxana.stoian@anpm.ro         Government
# 2   P       Elena GIUREA       elena.giurea@anpm.ro         Government
# 3   P         Silvia ENE         silvia.ene@apnm.ro         Government
# 4   P  Laurentiu APOSTOL  laurentiu.apostol@anpm.ro         Government
#
#                                  AFFILIATION\nNAME  COUNTRY     TYPE  \
# 0  ANPM/DCNB (National Agency for Env. Protection)  Romania  Partner
# 1  ANPM/DCNB (National Agency for Env. Protection)  Romania  Partner
# 2  ANPM/DCNB (National Agency for Env. Protection)  Romania  Partner
# 3  ANPM/DCNB (National Agency for Env. Protection)  Romania  Partner
# 4  ANPM/DCNB (National Agency for Env. Protection)  Romania  Partner
#
#   COUNTRY.1 START\nDATE  LENGTH\n(# OF DAYS)  100 LEVEL\n(INTRO)  \
# ...

# %%
data16 = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name='2016')
data16.head()
# Out:
#   P/I              NAME                       E-MAIL AFFILIATION \nTYPE  \
# 0   I      Katie Arkema         karkema@stanford.edu           Academic
# 1   I  Nirmal Bhagabati   nirmal.bhagabati@wwfus.org                NGO
# 2   I    Will Bierbower  will.bierbower@stanford.edu           Academic
# 3   I   Henry Borrebach       borrebach@stanford.edu           Academic
# 4   I       Leah Bremer            lbremer@gmail.com           Academic
#
#          AFFILIATION\nNAME COUNTRY       TYPE COUNTRY.1 START\nDATE  \
# 0  Natural Capital Project     USA  Symposium       USA  2016-03-21
# 1  Natural Capital Project     USA  Symposium       USA  2016-03-21
# 2  Natural Capital Project     USA  Symposium       USA  2016-03-21
# 3  Natural Capital Project     USA  Symposium       USA  2016-03-21
# 4  Natural Capital Project     USA  Symposium       USA  2016-03-21
#
#    LENGTH\n(# OF DAYS)  100 LEVEL\n(INTRO)  200 LEVEL\n(INTERMEDIATE)  \
# ...

# %%
data15 = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name='2015')
data15.head()
# Out:
#   P/I                      NAME                            E-MAIL  \
# 0   I             Gregg Verutes             gverutes@stanford.edu
# 1   I                Ben Gilmer  bgilmer@downstreamstrategies.com
# 2   P              Kareem Sabir             ksabir@coastal.gov.bb
# 3   P  Caroline Bissada-Gooding   cbissada-gooding@coastal.gov.bb
# 4   P   Fabian Hinds (Director)             fhinds@coastal.gov.bb
#
#   AFFILIATION \nTYPE        AFFILIATION\nNAME   COUNTRY     TYPE COUNTRY.1  \
# 0           Academic  Natural Capital Project       USA  Partner  Barbados
# 1         Consulting    Downstream Strategies       USA  Partner  Barbados
# 2              Gov't                     CZMU  Barbados  Partner  Barbados
# 3              Gov't                     CZMU  Barbados  Partner  Barbados
# 4              Gov't                     CZMU  Barbados  Partner  Barbados
#
#   START\nDATE  LENGTH\n(# OF DAYS)  100 LEVEL\n(INTRO)  \
# 0  2015-01-27                  3.0                 1.0
# ...

# %%
data14 = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name='2014')
data14.head()
# Out:
#   P/I              NAME                      E-MAIL AFFILIATION \nTYPE  \
# 0   I  Nirmal Bhagabati  nirmal.bhagabati@wwfus.org                NGO
# 1   I     Amy Rosenthal     amy.rosenthal@wwfus.org                NGO
# 2   I     Nasser Olwero     nasser.olwero@wwfus.org                NGO
# 3   P   Kenneth Bagstad          kjbagstad@usgs.gov              Gov't
# 4   P      Chelsea Berg        ceb1012@plymouth.edu           Academic
#
#              AFFILIATION\nNAME COUNTRY   TYPE COUNTRY.1 START\nDATE  \
# 0  WWF/Natural Capital Project     USA  Intro       USA  2014-12-07
# 1  WWF/Natural Capital Project     USA  Intro       USA  2014-12-07
# 2  WWF/Natural Capital Project     USA  Intro       USA  2014-12-07
# 3                         USGS     USA  Intro       USA  2014-12-07
# 4    Plymouth State University     USA  Intro       USA  2014-12-07
#
#    LENGTH\n(# OF DAYS)  100 LEVEL\n(INTRO)  200 LEVEL\n(INTERMEDIATE)  \
# ...

# %%
data13 = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name='2013')
data13.head()
# Out:
#   P/I              NAME E-MAIL AFFILIATION \nTYPE        AFFILIATION\nNAME  \
# 0   I  Mary Ruckelshaus    NaN           Academic  Natural Capital Project
# 1   I       Anne Guerry    NaN           Academic  Natural Capital Project
# 2   I      Spencer Wood    NaN           Academic  Natural Capital Project
# 3   I    Robert Griffin    NaN           Academic  Natural Capital Project
# 4   I       Jess Silver    NaN           Academic  Natural Capital Project
#
#   COUNTRY   TYPE  COUNTRY.1 START\nDATE  LENGTH\n(# OF DAYS)  \
# 0     USA  Nodal  Argentina  2013-09-12                  2.0
# 1     USA  Nodal  Argentina  2013-09-12                  2.0
# 2     USA  Nodal  Argentina  2013-09-12                  2.0
# 3     USA  Nodal  Argentina  2013-09-12                  2.0
# 4     USA  Nodal  Argentina  2013-09-12                  2.0
#
#    100 LEVEL\n(INTRO)  200 LEVEL\n(INTERMEDIATE)  300 LEVEL\n(ADVANCED)
# 0                 1.0                        1.0                    NaN
# ...

# %%
len(data18.COUNTRY.unique())
# Out:
# 43

# %%
len(data17.COUNTRY.unique())
# Out:
# 34

# %%
len(data16.COUNTRY.unique())
# Out:
# 43

# %%
len(data15.COUNTRY.unique())
# Out:
# 44

# %%
a = data18['200 LEVEL\n(INTERMEDIATE)']

# %%
a[a>0]
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      1.0
# 8      1.0
# 9      1.0
# 10     1.0
# 11     1.0
# 12     1.0
# 13     1.0
# 14     1.0
# 15     1.0
# 16     1.0
# 17     1.0
# 18     1.0
# 19     1.0
# 20     1.0
# 21     1.0
# 22     1.0
# 23     1.0
# 24     1.0
# 25     1.0
# 26     1.0
# 27     1.0
# 28     1.0
# 29     1.0
#       ...
# 370    1.0
# 371    1.0
# 372    1.0
# 373    1.0
# 374    1.0
# 375    2.0
# 376    2.0
# 377    2.0
# 378    2.0
# 379    2.0
# 380    2.0
# 381    2.0
# 382    2.0
# 383    2.0
# 384    2.0
# 385    2.0
# 779    1.0
# 780    1.0
# 781    1.0
# 782    1.0
# 783    1.0
# 784    1.0
# 785    1.0
# 786    1.0
# 787    1.0
# 788    1.0
# 789    1.0
# 790    1.0
# 791    1.0
# 792    1.0
# Name: 200 LEVEL\n(INTERMEDIATE), Length: 387, dtype: float64

# %%
data13['100 LEVEL\n(INTRO)'].sum()
# Out:
# 1090.0

# %%
data14['100 LEVEL\n(INTRO)'].sum()
# Out:
# 636.6410000000001

# %%
data15['100 LEVEL\n(INTRO)'].sum()
# Out:
# 961.329

# %%
data16['100 LEVEL\n(INTRO)'].sum()
# Out:
# 1051.75

# %%
data17['100 LEVEL\n(INTRO)'].sum()
# Out:
# 3458.0

# %%
data18['100 LEVEL\n(INTRO)'].sum()
# Out:
# 1923.0

# %%
data = pd.read_excel('PARTICIPANT LISTS - 2013-present.xlsx', skiprows=1, sheet_name=None)
data
# Out:
# OrderedDict([('2018',
#                   P/I                           NAME                              E-MAIL  \
#               0     P           Susana Beatriz Adamo          sadamo@ciesin.columbia.edu
#               1     P                      SoEun Ahn                     seahn@kei.re.kr
#               2     P              Mustapha Alhassan                                 NaN
#               3     P                    Karen Allen              karen.allen@furman.edu
#               4     P               Ginger Allington                  gallington@gwu.edu
#               5     P          Ibone Ametzaga Arregi              ibone.ametzaga@ehu.eus
#               6     P              Clarissa Anderson                   clrander@ucsd.edu
#               7     P                 Erik Andersson                erik.andersson@su.se
#               8     P                    Jay Angerer              jangerer@brc.tamus.edu
# ...

# %%
data['2018']
# Out:
#     P/I                           NAME                              E-MAIL  \
# 0     P           Susana Beatriz Adamo          sadamo@ciesin.columbia.edu
# 1     P                      SoEun Ahn                     seahn@kei.re.kr
# 2     P              Mustapha Alhassan                                 NaN
# 3     P                    Karen Allen              karen.allen@furman.edu
# 4     P               Ginger Allington                  gallington@gwu.edu
# 5     P          Ibone Ametzaga Arregi              ibone.ametzaga@ehu.eus
# 6     P              Clarissa Anderson                   clrander@ucsd.edu
# 7     P                 Erik Andersson                erik.andersson@su.se
# 8     P                    Jay Angerer              jangerer@brc.tamus.edu
# 9     P                  Stuart Anstee             stuart@stuartanstee.com
# 10    P  Deissy Andrea Arango Gonzalez               ranarango@hotmail.com
# ...

# %%
plt.plot(range(2013,2019),[data[str(year)]['100 LEVEL\n(INTRO)'].sum() for year in range(2013,2019)])
plt.title('100 LEVEL\n(INTRO)')
# Out:
# Text(0.5,1,'100 LEVEL\n(INTRO)')

# %%
plt.plot(range(2013,2019),[data[str(year)]['200 LEVEL\n(INTERMEDIATE)'].sum() for year in range(2013,2019)])
plt.title('200 LEVEL\n(INTERMEDIATE)')
# Out:
# Text(0.5,1,'200 LEVEL\n(INTERMEDIATE)')

# %%
plt.plot(range(2013,2019),[data[str(year)]['300 LEVEL\n(ADVANCED)'].sum() for year in range(2013,2019)])
plt.title('300 LEVEL\n(ADVANCED)')
# Out:
# Text(0.5,1,'300 LEVEL\n(ADVANCED)')

# %%
plt.plot(range(2013,2019),[len(data[str(year)]['AFFILIATION\nNAME'].unique()) for year in range(2013,2019)])
plt.title('AFFILIATION\nNAME')
# Out:
# Text(0.5,1,'AFFILIATION\nNAME')

# %%
plt.plot(range(2013,2019),[len(data[str(year)]['COUNTRY'].unique()) for year in range(2013,2019)])
plt.title('COUNTRY')
# Out:
# Text(0.5,1,'COUNTRY')

# %%
plt.plot(range(2013,2019),[len(data[str(year)]['NAME'].unique()) for year in range(2013,2019)])
plt.title('NAME')
# Out:
# Text(0.5,1,'NAME')
